# %% [markdown]
# ## Binary Tree Paths
#
# Given the root of a binary tree, return all root-to-leaf paths in any order. A leaf is a node with no children. Each path should be returned as a string of node values separated by `->` symbols.
# Example 1:
# Input:
# `["1,2,3,null,5"]`
# Output:
# `["1->2->5","1->3"]`
#
# Example 2:
# Input:
# `["1"]`
# Output:
# `["1"]`
#
# ### Constraints:
# * The number of nodes in the tree is in the range [1, 100]
# * Node.val is in the range [-100, 100]

# %%
"""
A custom TreeNode class
"""
from typing import Optional, List

class TreeNode:
    
    def __init__(self, value: int = 0, left: int = None, right: int = None):
        self.value = value
        self.left = left
        self.right = right


class BinaryTreePaths:

    def binary_tree_paths(self, root: Optional[TreeNode]) -> List[str]:
        paths = []
        self.dfs(root, '', paths)
        return paths

    def dfs(self, node: Optional[TreeNode], path, paths):

        if node is None:
            return
        
        current_path = path + str(node.value)

        if node.left is None and node.right is None:
            paths.append(current_path)
            return
        
        if node.left:
            self.dfs(node.left, current_path + ' -> ', paths)
        
        if node.right:
            self.dfs(node.right, current_path + ' -> ', paths)

obj = BinaryTreePaths()
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(7)
root.right.left = TreeNode(5)
root.right.right = TreeNode(6)

obj.binary_tree_paths(root)
# Out:
# ['1 -> 2 -> 7', '1 -> 3 -> 5', '1 -> 3 -> 6']
